# %%
import glob

import pandas as pd

# %%
tweets = pd.concat(pd.read_csv(f) for f in glob.glob('tweet_data/*.csv'))

# %%
texts = tweets.text.values

# %%
from collections import Counter

c = Counter(tok for text in texts for tok in text.split())
c.most_common()
# Out:
# [('the', 146196),
#  ('to', 135426),
#  ('RT', 101692),
#  ('of', 75821),
#  ('in', 72521),
#  ('for', 64954),
#  ('a', 60884),
#  ('and', 54334),
#  ('on', 50872),
#  ('with', 38160),
#  ('is', 36544),
#  ('at', 36496),
#  ('&amp;', 34395),
#  ('#auspol', 32428),
#  ('-', 26863),
#  ('I', 21740),
#  ('be', 19310),
#  ('you', 18560),
#  ('from', 17736),
#  ('this', 17525),
#  ('about', 16375),
#  ('will', 16334),
#  ('The', 15042),
#  ('by', 14977),
#  ('our', 14894),
#  ('that', 14243),
#  ('have', 14165),
#  ('are', 13939),
#  ('it', 13381),
#  ('Great', 11879),
#  ('has', 11492),
#  ('not', 11430),
#  ('my', 11306),
#  ('as', 11065),
#  ('Labor', 10897),
#  ('up', 9696),
#  ('we', 9503),
#  ('great', 9428),
#  ('was', 9338),
#  ('today', 9026),
#  ('all', 8989),
#  ('new', 8661),
#  ('out', 8645),
#  ('an', 8582),
#  ('your', 8372),
#  ('more', 8153),
#  ('their', 7448),
#  ('A', 7371),
#  ('his', 7308),
#  ('but', 7090),
#  ('Abbott', 6618),
#  ('just', 6579),
#  ('who', 6509),
#  ('support', 6305),
#  ('Australian', 6242),
#  ('Australia', 6075),
#  ('people', 5839),
#  ('can', 5730),
#  ('no', 5721),
#  ('now', 5569),
#  ('he', 5467),
#  ('they', 5409),
#  ('see', 5392),
#  ('Thanks', 5231),
#  ('#ausvotes', 5220),
#  ('so', 5129),
#  ('tax', 5035),
#  ('says', 4915),
#  ('what', 4862),
#  ('good', 4799),
#  ('We', 4750),
#  ('get', 4739),
#  ('day', 4655),
#  ('Govt', 4631),
#  ('Minister', 4628),
#  ('been', 4596),
#  ('With', 4463),
#  ('time', 4442),
#  ('morning', 4395),
#  ('do', 4392),
#  ('if', 4361),
#  ('than', 4360),
#  ('over', 4357),
#  ('me', 4321),
#  ('or', 4270),
#  ('one', 4250),
#  ('via', 4201),
#  ('local', 4187),
#  ('#politas', 4129),
#  ('how', 4089),
#  ('into', 4064),
#  ('should', 4001),
#  ('last', 4001),
#  ('Turnbull', 3993),
#  ('work', 3937),
#  ('need', 3915),
#  ('This', 3904),
#  ('like', 3856),
#  ('My', 3846),
#  ('would', 3775),
#  ('At', 3767),
#  ('after', 3755),
#  ('...', 3660),
#  ('PM', 3660),
#  ('community', 3604),
#  ('jobs', 3525),
#  ('today.', 3467),
#  ('Parliament', 3409),
#  ("Labor's", 3396),
#  ('back', 3371),
#  ('very', 3352),
#  ('cuts', 3338),
#  ('first', 3322),
#  ('thanks', 3306),
#  ('when', 3281),
#  ('some', 3272),
#  ('#qt', 3264),
#  ('In', 3214),
#  ('funding', 3213),
#  ('2', 3127),
#  ('Tony', 3099),
#  ('Government', 3062),
#  ('against', 3036),
#  ('Day', 3032),
#  ('Senate', 3013),
#  ('plan', 3013),
#  ('make', 2997),
#  ('Just', 2990),
#  ('It', 2989),
#  ('us', 2975),
#  ('Good', 2960),
#  ('years', 2956),
#  ("I'm", 2933),
#  ("it's", 2882),
#  ('here', 2873),
#  ('policy', 2862),
#  ('help', 2831),
#  ('talking', 2797),
#  ('only', 2795),
#  ('its', 2782),
#  ('What', 2770),
#  ('being', 2746),
#  ('off', 2743),
#  ('why', 2738),
#  ('health', 2727),
#  ('under', 2716),
#  ("don't", 2710),
#  ('year', 2692),
#  ('…', 2689),
#  ('there', 2675),
#  ('big', 2664),
#  ('If', 2647),
#  ('forward', 2641),
#  ('http…', 2639),
#  ('speech', 2634),
#  ('National', 2604),
#  ("It's", 2601),
#  ('say', 2598),
#  ('go', 2575),
#  ('must', 2575),
#  ('next', 2563),
#  ('Congratulations', 2557),
#  ('know', 2551),
#  ('campaign', 2530),
#  ('still', 2515),
#  ('had', 2513),
#  ('budget', 2501),
#  ('many', 2486),
#  ('business', 2455),
#  ('New', 2452),
#  ('launch', 2433),
#  ('down', 2416),
#  ('Bill', 2414),
#  ('want', 2407),
#  ('You', 2402),
#  ('tonight', 2388),
#  ('Australians', 2370),
#  ('best', 2349),
#  ('way', 2348),
#  ('@TurnbullMalcolm', 2338),
#  ('Today', 2337),
#  ('@', 2330),
#  ('cut', 2329),
#  ('Liberal', 2328),
#  ('her', 2323),
#  ('done', 2318),
#  ('htt…', 2298),
#  ('team', 2277),
#  ('4', 2259),
#  ('Coalition', 2243),
#  ('them', 2235),
#  ('House', 2233),
#  ('No', 2210),
#  ('much', 2207),
#  ('meeting', 2202),
#  ('MP', 2197),
#  ('meet', 2196),
#  ('better', 2190),
#  ('think', 2178),
#  ('were', 2176),
#  ('future', 2170),
#  ('week', 2167),
#  ('take', 2166),
#  ('On', 2159),
#  ('Our', 2156),
#  ('those', 2154),
#  ('election', 2153),
#  ('So', 2136),
#  ('women', 2101),
#  ('public', 2089),
#  ('change', 2077),
#  ('students', 2057),
#  ('part', 2054),
#  ('join', 2043),
#  ('talk', 2043),
#  ('which', 2040),
#  ('Canberra', 2013),
#  ('well', 1997),
#  ('And', 1979),
#  ('Sydney', 1967),
#  ('another', 1955),
#  ('@billshortenmp', 1952),
#  ('night', 1942),
#  ('|', 1929),
#  ('govt', 1928),
#  ('am', 1927),
#  ('news', 1918),
#  ("Australia's", 1908),
#  ('Congrats', 1903),
#  ('@TonyAbbottMHR', 1900),
#  ('going', 1899),
#  ('Thank', 1892),
#  ('Senator', 1880),
#  ('government', 1880),
#  ('before', 1863),
#  ('young', 1861),
#  ('said', 1860),
#  ('could', 1860),
#  ('vote', 1847),
#  ('carbon', 1843),
#  ("can't", 1824),
#  ('Malcolm', 1811),
#  ('family', 1778),
#  ('Greens', 1773),
#  ('w', 1770),
#  ('climate', 1765),
#  ('visit', 1762),
#  ('right', 1757),
#  ('small', 1746),
#  ('pay', 1746),
#  ('most', 1739),
#  ('did', 1713),
#  ('made', 1713),
#  ('NSW', 1705),
#  ('school', 1705),
#  ('–', 1700),
#  ('ABC', 1697),
#  ('million', 1690),
#  ('where', 1686),
#  ('Aust', 1685),
#  ('How', 1678),
#  ('economic', 1678),
#  ('Well', 1674),
#  ('School', 1670),
#  ('1', 1670),
#  ('@billshortenmp:', 1669),
#  ('hear', 1662),
#  ('ht…', 1647),
#  ('@JulieBishopMP', 1646),
#  ('Federal', 1646),
#  ('education', 1632),
#  ('any', 1630),
#  ('care', 1627),
#  ('working', 1622),
#  ('Happy', 1617),
#  ('job', 1615),
#  ('important', 1614),
#  ('every', 1614),
#  ('Not', 1606),
#  ('speak', 1602),
#  ('win', 1596),
#  ('world', 1593),
#  ('never', 1591),
#  ('discuss', 1591),
#  ('More', 1587),
#  ('other', 1581),
#  ('keep', 1574),
#  ('needs', 1564),
#  ('3', 1563),
#  ('NBN', 1557),
#  ('real', 1556),
#  ('Shorten', 1546),
#  ('too', 1542),
#  ('look', 1542),
#  ('national', 1530),
#  ('looking', 1523),
#  ('stop', 1523),
#  ('start', 1522),
#  ('since', 1520),
#  ('Looking', 1515),
#  ('supporting', 1507),
#  ('Budget', 1506),
#  ('got', 1506),
#  ('industry', 1503),
#  ('it.', 1488),
#  ('doing', 1486),
#  ('WA', 1484),
#  ('workers', 1476),
#  ('proud', 1474),
#  ('http://…', 1470),
#  ('report', 1468),
#  ('office', 1466),
#  ('kids', 1465),
#  ('service', 1464),
#  ('opening', 1463),
#  ('home', 1458),
#  ('come', 1454),
#  ('Community', 1452),
#  ('St', 1451),
#  ('http:…', 1450),
#  ('About', 1448),
#  ('State', 1448),
#  ('own', 1443),
#  ('families', 1442),
#  ('live', 1442),
#  ('morning.', 1442),
#  ('billion', 1441),
#  ('http:/…', 1431),
#  ('does', 1431),
#  ('here:', 1427),
#  ('speaking', 1424),
#  ('show', 1420),
#  ('put', 1406),
#  ('Centre', 1401),
#  ('through', 1398),
#  ('@AustralianLabor:', 1397),
#  ('give', 1391),
#  ('debate', 1385),
#  ('SA', 1383),
#  ('re', 1382),
#  ('open', 1372),
#  ('http://t…', 1365),
#  ('@AlboMP', 1363),
#  ('https:/…', 1361),
#  ('.', 1360),
#  ('always', 1360),
#  ("today's", 1358),
#  ('Mr', 1355),
#  ('https://…', 1354),
#  ('John', 1354),
#  ('also', 1348),
#  ('end', 1345),
#  ('https:…', 1343),
#  ('again', 1343),
#  ('even', 1340),
#  ('strong', 1338),
#  ('really', 1338),
#  ('South', 1336),
#  ("Abbott's", 1332),
#  ('Libs', 1332),
#  ('ALP', 1328),
#  ('https…', 1328),
#  ('economy', 1325),
#  ('around', 1310),
#  ('https://t…', 1309),
#  ('two', 1301),
#  ('Very', 1300),
#  ('Aus', 1299),
#  ('growth', 1298),
#  ('Medicare', 1292),
#  ('Why', 1290),
#  ('welcome', 1288),
#  ('media', 1282),
#  ('read', 1277),
#  ('then', 1276),
#  ('getting', 1274),
#  ('call', 1274),
#  ('making', 1273),
#  ('sure', 1268),
#  ('announced', 1260),
#  ('http://t.…', 1259),
#  ('because', 1259),
#  ('political', 1257),
#  ('him', 1241),
#  ('issues', 1239),
#  ('cost', 1236),
#  ('candidate', 1235),
#  ('these', 1222),
#  ('Health', 1214),
#  ('services', 1213),
#  ('long', 1211),
#  ("won't", 1211),
#  ('Peter', 1210),
#  ('All', 1208),
#  ('Tax', 1205),
#  ('chat', 1204),
#  ('Club', 1202),
#  ('Liberals', 1201),
#  ('regional', 1197),
#  ('He', 1194),
#  ("doesn't", 1193),
#  ('investment', 1192),
#  ('@AustralianLabor', 1192),
#  ('wonderful', 1191),
#  ('hard', 1191),
#  ('Party', 1187),
#  ('members', 1185),
#  ('same', 1180),
#  ('everyone', 1173),
#  ('love', 1171),
#  ('between', 1164),
#  ('country', 1163),
#  ('Now', 1159),
#  ('Will', 1158),
#  ('forum', 1155),
#  ('action', 1153),
#  ('Council', 1152),
#  ('http://t.c…', 1142),
#  ('changes', 1138),
#  ('interview', 1138),
#  ('children', 1137),
#  ('debt', 1135),
#  ('announce', 1131),
#  ('money', 1129),
#  ('event', 1128),
#  ('Park', 1125),
#  ('deal', 1124),
#  ('https://t.…', 1123),
#  ('full', 1118),
#  ('As', 1111),
#  ('@SkyNewsAust', 1111),
#  ('story', 1111),
#  ('wants', 1110),
#  ('They', 1110),
#  ('h…', 1104),
#  ('free', 1104),
#  ('@GrahamPerrettMP', 1103),
#  ('Another', 1101),
#  ('For', 1098),
#  ('spoke', 1097),
#  ('2015', 1097),
#  ('thank', 1096),
#  ('stand', 1090),
#  ('happy', 1087),
#  ('across', 1086),
#  ('@LiberalAus:', 1084),
#  ('Big', 1083),
#  ('Hockey', 1078),
#  ('Coast', 1076),
#  ("didn't", 1067),
#  ('higher', 1067),
#  ('+', 1062),
#  ('schools', 1058),
#  ('An', 1058),
#  ('@rharris334', 1057),
#  ('Prime', 1053),
#  ('GP', 1051),
#  ('parliament', 1051),
#  ("I'll", 1050),
#  ('Gov', 1047),
#  ('days', 1047),
#  ('trade', 1047),
#  ('Speaking', 1047),
#  ('she', 1045),
#  ('shows', 1044),
#  ('party', 1043),
#  ('Aussie', 1043),
#  ('https://t.c…', 1042),
#  ('Melbourne', 1041),
#  ('old', 1041),
#  ('#MyLiberal', 1039),
#  ('coming', 1033),
#  ('question', 1024),
#  ('http://t.co…', 1021),
#  ('w/', 1021),
#  ('catch', 1019),
#  ('ever', 1016),
#  ('piece', 1016),
#  ('David', 1012),
#  ("that's", 1010),
#  ('research', 1009),
#  ('taking', 1006),
#  ('without', 1003),
#  ('hope', 1002),
#  ('West', 997),
#  ("I've", 994),
#  ('But', 993),
#  ("you're", 988),
#  ('Year', 987),
#  ('program', 986),
#  ('5', 982),
#  ('fight', 979),
#  ('Media', 977),
#  ('World', 976),
#  ('fantastic', 975),
#  ('find', 973),
#  ('@DrGCrisp', 973),
#  ('Is', 972),
#  ('Andrew', 966),
#  ('such', 963),
#  ('@DarrenChesterMP', 963),
#  ('US', 961),
#  ('run', 959),
#  ('increase', 958),
#  ('address', 958),
#  ('tonight.', 958),
#  ('while', 956),
#  ('Australia.', 950),
#  ('having', 950),
#  (':)', 949),
#  ('6', 948),
#  ('@cpyne', 947),
#  ('lost', 946),
#  ('life', 946),
#  ('set', 945),
#  ('state', 944),
#  ('tomorrow', 943),
#  ("Here's", 943),
#  ('deliver', 942),
#  ('Business', 939),
#  ('Go', 937),
#  ('tell', 936),
#  ('High', 931),
#  ('There', 930),
#  ('staff', 929),
#  ('^Staff', 927),
#  ('10', 927),
#  ('honour', 926),
#  ('#ausdef', 924),
#  ('Gillard', 924),
#  ('China', 923),
#  ('during', 922),
#  ('Read', 918),
#  ('plans', 916),
#  ('reform', 915),
#  ('commitment', 912),
#  ('infrastructure', 911),
#  ('@smh', 911),
#  ('energy', 910),
#  ('violence', 910),
#  ('https://t.co…', 904),
#  ('build', 903),
#  ('latest', 903),
#  ('@Birmo', 902),
#  ('Adelaide', 902),
#  ('little', 900),
#  ('use', 900),
#  ('Have', 900),
#  ('See', 899),
#  ('questions', 899),
#  ('LNP', 898),
#  ('may', 893),
#  ('leaders', 892),
#  ('North', 891),
#  ('high', 889),
#  ('early', 887),
#  ('beautiful', 886),
#  ('Christmas', 886),
#  ('both', 885),
#  ('politics', 884),
#  ('amazing', 884),
#  ('record', 882),
#  ('@Barnaby_Joyce', 881),
#  ('@TonyAbbottMHR:', 881),
#  ('inquiry', 878),
#  ('1st', 875),
#  ('Watch', 872),
#  ('fair', 872),
#  ('Fantastic', 870),
#  ('2014', 867),
#  ('impact', 865),
#  ('businesses', 864),
#  ('#Auspol', 862),
#  ('spending', 856),
#  ('Please', 856),
#  ('http://t.co/…', 855),
#  ('hearing', 855),
#  ("Turnbull's", 855),
#  ("Don't", 855),
#  ('One', 855),
#  ('discussing', 854),
#  ('photo', 853),
#  ('attack', 851),
#  ('To', 849),
#  ('Oz', 848),
#  ('Indigenous', 848),
#  ('road', 847),
#  ('few', 846),
#  ('left', 845),
#  ('child', 843),
#  ('bad', 841),
#  ('discussion', 838),
#  ('Talking', 837),
#  ('place', 837),
#  ('conference', 836),
#  ('Proud', 835),
#  ('power', 835),
#  ('Qld', 834),
#  ('&', 833),
#  ('issue', 831),
#  ('Time', 829),
#  ('Only', 827),
#  ('MPs', 826),
#  ('friends', 826),
#  ('innovation', 822),
#  ('ready', 818),
#  ('top', 818),
#  ('@fitzhunter', 817),
#  ('water', 817),
#  ('less', 817),
#  ('Here', 815),
#  ('protect', 814),
#  ('Labor’s', 814),
#  ('luck', 812),
#  ('income', 812),
#  ('Facebook', 811),
#  ('nothing', 807),
#  ('leadership', 806),
#  ('already', 804),
#  ('mobile', 804),
#  ('asked', 803),
#  ('thing', 803),
#  ('man', 803),
#  ('Rudd', 803),
#  ('share', 799),
#  ('save', 794),
#  ('Fed', 793),
#  ('promise', 793),
#  ('First', 790),
#  ('decision', 788),
#  ('President', 786),
#  ('believe', 786),
#  ('super', 784),
#  ('system', 779),
#  ('things', 779),
#  ('response', 779),
#  ('Defence', 779),
#  ('calls', 776),
#  ('let', 775),
#  ('video', 774),
#  ('afternoon', 772),
#  ('News', 772),
#  ('announcement', 771),
#  ('When', 771),
#  ('Brisbane', 770),
#  ('2013', 769),
#  ('building', 769),
#  ('federal', 768),
#  ('fund', 766),
#  ('electorate', 766),
#  ('#NBN', 763),
#  ('#qanda', 761),
#  ('game', 760),
#  ('Chris', 759),
#  ('volunteers', 758),
#  ('global', 758),
#  ('until', 758),
#  ('answer', 758),
#  ('Perth', 757),
#  ('#Canberra', 757),
#  ('today,', 756),
#  ('article', 756),
#  ('Check', 755),
#  ('Dr', 753),
#  ('means', 752),
#  ('@Wyatt_MP', 750),
#  ('agree', 750),
#  ('actually', 749),
#  ('Forum', 748),
#  ('tells', 747),
#  ('met', 745),
#  ('Joe', 744),
#  ('release', 743),
#  ('statement', 742),
#  ("he's", 741),
#  ('Aboriginal', 740),
#  ('former', 740),
#  ('calling', 740),
#  ('away', 739),
#  ('policies', 739),
#  ('farmers', 738),
#  ('rate', 738),
#  ('Carbon', 735),
#  ('Western', 734),
#  ('friend', 732),
#  ('close', 732),
#  ('hit', 731),
#  ('watch', 731),
#  ('science', 730),
#  ('#auspoI', 730),
#  ('ahead', 729),
#  ('yesterday', 728),
#  ('!', 727),
#  ('https://t.co/…', 727),
#  ('Public', 726),
#  ('bill', 726),
#  ('@larissawaters', 725),
#  ('front', 723),
#  ('centre', 721),
#  ('makes', 721),
#  ('project', 720),
#  ('That', 719),
#  ('foreign', 719),
#  ('saying', 719),
#  ('opportunity', 718),
#  ('sector', 718),
#  ('East', 717),
#  ('rates', 716),
#  ('safe', 716),
#  ('@EwenJonesMP', 715),
#  ('lot', 715),
#  ('GST', 714),
#  ('@TurnbullMalcolm:', 712),
#  ('please', 708),
#  ('#fb', 707),
#  ('behind', 706),
#  ('role', 704),
#  ('Paul', 704),
#  ('giving', 704),
#  ('food', 700),
#  ('celebrate', 700),
#  ('laws', 695),
#  ('trying', 693),
#  ('helping', 693),
#  ('you.', 693),
#  ('raise', 693),
#  ('called', 691),
#  ('yet', 691),
#  ("Govt's", 689),
#  ('social', 689),
#  ('bring', 688),
#  ('might', 688),
#  ('including', 686),
#  ('evidence', 684),
#  ('paid', 683),
#  ('gets', 683),
#  ('clear', 682),
#  ('CEO', 682),
#  ('Member', 681),
#  ("We're", 680),
#  ('Service', 679),
#  ('wrong', 679),
#  ('message', 679),
#  ('@Tony_Burke', 678),
#  ('@JoshFrydenberg', 678),
#  ('mining', 678),
#  ('#lovegippsland', 677),
#  ('pleasure', 677),
#  ('2016', 676),
#  ('12', 675),
#  ('Parliamentary', 674),
#  ('ppl', 672),
#  ('@SenatorWong', 672),
#  ('voting', 671),
#  ('@JoeHockey', 671),
#  ('info', 671),
#  ('voted', 670),
#  ("we're", 669),
#  ('thought', 668),
#  ('locals', 668),
#  ('Bob', 665),
#  ('access', 664),
#  ('thoughts', 664),
#  ('given', 663),
#  ('interest', 662),
#  ("That's", 662),
#  ('visiting', 660),
#  ('Geelong', 659),
#  ('Central', 658),
#  ('Awards', 657),
#  ('remember', 656),
#  ('training', 656),
#  ('ago', 655),
#  ('leader', 653),
#  ('house', 653),
#  ('Commission', 652),
#  ('International', 652),
#  ('low', 652),
#  ('Come', 651),
#  ('Tas', 650),
#  ('Lib', 650),
#  ('celebrating', 649),
#  ('ask', 649),
#  ('posted', 648),
#  ('line', 648),
#  ('Scott', 648),
#  ('living', 648),
#  ('told', 648),
#  ('Best', 647),
#  ('Treasurer', 647),
#  ('positive', 647),
#  ('dinner', 646),
#  ('final', 646),
#  ('Kevin', 645),
#  ('Michael', 644),
#  ('Pleased', 643),
#  ('Queensland', 637),
#  ('After', 635),
#  ('George', 635),
#  ('lives', 634),
#  ('importance', 633),
#  ('bit', 633),
#  ('Meeting', 632),
#  ('Morrison', 631),
#  ('Last', 631),
#  ('@tanya_plibersek', 629),
#  ('far', 628),
#  ('committed', 628),
#  ("isn't", 625),
#  ('sign', 624),
#  ('per', 624),
#  ('100', 623),
#  ('key', 622),
#  ('lead', 620),
#  ('broken', 619),
#  ('Shadow', 618),
#  ('opportunities', 618),
#  ('crowd', 617),
#  ('Team', 617),
#  ('Join', 617),
#  ('turn', 616),
#  ('u', 616),
#  ('book', 615),
#  ('#QT', 614),
#  ('@LaborHerald:', 614),
#  ('Royal', 613),
#  ('create', 613),
#  ('@latikambourke', 612),
#  ('goes', 611),
#  ('standing', 611),
#  ('Australia’s', 610),
#  ('@AndrewRobbMP', 608),
#  ('Pyne', 606),
#  ('Vic', 606),
#  ('seen', 606),
#  ('half', 606),
#  ('used', 605),
#  ('Mayor', 605),
#  ('@abcnews', 604),
#  ('huge', 603),
#  ('link', 603),
#  ('security', 602),
#  ('@edhusicMP', 601),
#  ('College', 601),
#  ('special', 601),
#  ('running', 600),
#  ('@ScottMorrisonMP', 600),
#  ('something', 599),
#  ('months', 598),
#  ('@ellenwhinnett', 597),
#  ('ensure', 597),
#  ('communities', 597),
#  ('past', 597),
#  ('Tasmanian', 597),
#  ('member', 595),
#  ('continue', 595),
#  ('@The_Nationals', 593),
#  ('group', 593),
#  ('Some', 593),
#  ('due', 592),
#  ('Mark', 592),
#  ('leave', 592),
#  ('case', 592),
#  ('safety', 591),
#  ('funds', 591),
#  ('check', 590),
#  ('came', 590),
#  ('joined', 589),
#  ('marriage', 589),
#  ('announcing', 589),
#  ('"The', 588),
#  ('Primary', 588),
#  ('together', 588),
#  ("Let's", 587),
#  ('Sunday', 587),
#  ('along', 587),
#  ('#…', 586),
#  ('Green', 584),
#  ('point', 584),
#  ('online', 583),
#  ('claims', 583),
#  ('Wonderful', 583),
#  ('v', 583),
#  ('rural', 582),
#  ('red', 582),
#  ('Hill', 582),
#  ('talks', 579),
#  ('residents', 579),
#  ('20', 578),
#  ('ANZAC', 577),
#  ('motion', 577),
#  ('now.', 576),
#  ('times', 575),
#  ('mate', 574),
#  ('@GChristensenMP', 573),
#  ('fix', 572),
#  ('Tasmania', 570),
#  ('price', 568),
#  ('mean', 568),
#  ('Trade', 567),
#  ('From', 565),
#  ('Plan', 563),
#  ('year.', 563),
#  ('needed', 562),
#  ('Port', 562),
#  ('soon', 561),
#  ("Government's", 561),
#  ('defence', 561),
#  ('anniversary', 560),
#  ('#AusPol', 560),
#  ('try', 559),
#  ('@BruceBillsonMP', 559),
#  ('youth', 559),
#  ('Committee', 558),
#  ('night.', 558),
#  ('cutting', 556),
#  ('Gold', 555),
#  ('Speech', 555),
#  ('#saparli', 555),
#  ('Education', 555),
#  ('Heading', 554),
#  ('Chinese', 554),
#  ('comes', 552),
#  ('@SenatorSurfer', 552),
#  ('company', 552),
#  ('LIVE', 552),
#  ('Young', 551),
#  ('fighting', 550),
#  ('Youth', 550),
#  ('minister', 550),
#  ('major', 550),
#  ('listening', 549),
#  ('history', 548),
#  ('Celebrating', 548),
#  ('drive', 547),
#  ('data', 546),
#  ('Local', 545),
#  ('clean', 544),
#  ('true', 544),
#  ('boost', 544),
#  ('promises', 544),
#  ('spend', 543),
#  ('three', 543),
#  ('missed', 543),
#  ('present', 543),
#  ('colleagues', 543),
#  ('i', 543),
#  ('costs', 542),
#  ('Love', 542),
#  ('head', 541),
#  ('parents', 541),
#  ('7', 539),
#  ('aged', 537),
#  ('Get', 536),
#  ('anyone', 536),
#  ('legislation', 535),
#  ('rights', 535),
#  ('Swan', 534),
#  ('comments', 534),
#  ('week.', 534),
#  ('#TPP', 533),
#  ('Foreign', 533),
#  ('@YouTube', 533),
#  ('Conference', 533),
#  ('day.', 533),
#  ('enough', 532),
#  ('provide', 532),
#  ('Festival', 531),
#  ('Hobart', 531),
#  ('promised', 531),
#  ('took', 531),
#  ('petition', 531),
#  ('launched', 530),
#  ('Bishop', 529),
#  ('review', 529),
#  ('@MathiasCormann', 528),
#  ('funded', 528),
#  ('Hope', 528),
#  ('@SHendersonMP', 528),
#  ('looks', 527),
#  ('taken', 526),
#  ("there's", 526),
#  ('Do', 525),
#  ('@SenatorWong:', 525),
#  ('number', 524),
#  ('second', 524),
#  ('refugees', 523),
#  ('biggest', 522),
#  ('view', 522),
#  ('using', 521),
#  ('asylum', 521),
#  ('Sky', 520),
#  ('send', 520),
#  ('delivering', 520),
#  ('someone', 519),
#  ('winning', 519),
#  ('@CatherineKingMP:', 518),
#  ('chance', 518),
#  ('focus', 518),
#  ('worth', 517),
#  ...]
